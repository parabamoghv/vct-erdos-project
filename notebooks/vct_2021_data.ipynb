# %% [markdown]
# VALORANT Champions Tour 2021 Data from https://www.kaggle.com/datasets/ryanluong1/valorant-champion-tour-2021-2023-data
# Original data source: https://www.vlr.gg/vct-2021

# %%
import pandas as pd

# %%
agents_pick_rates = pd.read_csv("../data/vct_2021/agents/agents_pick_rates.csv")
agents_pick_rates.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 1  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 2  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 3  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 4  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
#
#                     Match Type       Map  Agent Pick Rate
# 0  Upper Bracket Quarterfinals  All Maps   jett       89%
# 1  Upper Bracket Quarterfinals  All Maps  astra       72%
# 2  Upper Bracket Quarterfinals  All Maps   sova       67%
# 3  Upper Bracket Quarterfinals  All Maps  viper       56%
# 4  Upper Bracket Quarterfinals  All Maps   skye       56%

# %%
maps_stats = pd.read_csv("../data/vct_2021/agents/maps_stats.csv")
maps_stats.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 1  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 2  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 3  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 4  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
#
#                     Match Type       Map  Total Maps Played  \
# 0  Upper Bracket Quarterfinals  All Maps                  9
# 1  Upper Bracket Quarterfinals    Ascent                  2
# 2  Upper Bracket Quarterfinals      Bind                  2
# 3  Upper Bracket Quarterfinals    Icebox                  2
# 4  Upper Bracket Quarterfinals    Breeze                  1
#
#   Attacker Side Win Percentage Defender Side Win Percentage
# 0                          41%                          59%
# 1                          35%                          65%
# ...

# %%
teams_picked_agents = pd.read_csv("../data/vct_2021/agents/teams_picked_agents.csv")
teams_picked_agents.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 1  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 2  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 3  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
# 4  Champions Tour Asia-Pacific: Last Chance Quali...  Main Event
#
#                     Match Type     Map        Team Agent Picked  \
# 0  Upper Bracket Quarterfinals  Ascent  FULL SENSE         jett
# 1  Upper Bracket Quarterfinals  Ascent  FULL SENSE        astra
# 2  Upper Bracket Quarterfinals  Ascent  FULL SENSE         sova
# 3  Upper Bracket Quarterfinals  Ascent  FULL SENSE      killjoy
# 4  Upper Bracket Quarterfinals  Ascent  FULL SENSE         kayo
#
#    Total Wins By Map  Total Loss By Map  Total Maps Played
# 0                  1                  0                  1
# 1                  1                  0                  1
# ...

# %%
players_ids = pd.read_csv("../data/vct_2021/ids/players_ids.csv")
players_ids.head()
# Out:
#   Player  Player ID
# 0   MaKo       4462
# 1   stax        485
# 2     Rb        488
# 3   k1Ng        771
# 4   BuZz        804

# %%
teams_ids = pd.read_csv("../data/vct_2021/ids/teams_ids.csv")
teams_ids.head()
# Out:
#               Team  Team ID
# 0  Vision Strikers    198.0
# 1       FULL SENSE   4050.0
# 2     Team Vikings    420.0
# 3    Crazy Raccoon    277.0
# 4           FNATIC   2593.0

# %%
tournaments_stages_match_types_ids = pd.read_csv("../data/vct_2021/ids/tournaments_stages_match_types_ids.csv")
tournaments_stages_match_types_ids.head()
# Out:
#                                           Tournament  Tournament ID  \
# 0  Champions Tour North America: Last Chance Qual...            558
# 1  Champions Tour North America: Last Chance Qual...            558
# 2  Champions Tour North America: Last Chance Qual...            558
# 3  Champions Tour North America: Last Chance Qual...            558
# 4  Champions Tour North America: Last Chance Qual...            558
#
#         Stage  Stage ID           Match Type  Match Type ID
# 0  Main Event    1094.0  Upper Quarterfinals         7644.0
# 1  Main Event    1094.0     Upper Semifinals         7645.0
# 2  Main Event    1094.0          Upper Final         7646.0
# 3  Main Event    1094.0          Grand Final         7647.0
# 4  Main Event    1094.0        Lower Round 1         7648.0

# %%
tournaments_stages_matches_games_ids = pd.read_csv("../data/vct_2021/ids/tournaments_stages_matches_games_ids.csv")
tournaments_stages_matches_games_ids.head()
# Out:
#                 Tournament  Tournament ID        Stage  Stage ID   Match Type  \
# 0  Valorant Champions 2021            449  Group Stage       945  Opening (D)
# 1  Valorant Champions 2021            449  Group Stage       945  Opening (D)
# 2  Valorant Champions 2021            449  Group Stage       945  Opening (C)
# 3  Valorant Champions 2021            449  Group Stage       945  Opening (C)
# 4  Valorant Champions 2021            449  Group Stage       945  Opening (D)
#
#                       Match Name  Match ID     Map  Game ID
# 0  Vision Strikers vs FULL SENSE     51282   Haven    57948
# 1  Vision Strikers vs FULL SENSE     51282  Breeze    57949
# 2  Team Vikings vs Crazy Raccoon     51278  Icebox    57936
# 3  Team Vikings vs Crazy Raccoon     51278   Haven    57937
# 4               FNATIC vs Cloud9     51283  Icebox    57951

# %%
draft_phase = pd.read_csv("../data/vct_2021/matches/draft_phase.csv")
draft_phase.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name             Team Action       Map
# 0  Vision Strikers vs FULL SENSE       FULL SENSE    ban  Fracture
# 1  Vision Strikers vs FULL SENSE  Vision Strikers    ban    Ascent
# 2  Vision Strikers vs FULL SENSE       FULL SENSE   pick     Haven
# 3  Vision Strikers vs FULL SENSE  Vision Strikers   pick    Breeze
# 4  Vision Strikers vs FULL SENSE       FULL SENSE    ban      Bind

# %%
eco_rounds = pd.read_csv("../data/vct_2021/matches/eco_rounds.csv")
eco_rounds.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name    Map  Round Number             Team  \
# 0  Vision Strikers vs FULL SENSE  Haven             1  Vision Strikers
# 1  Vision Strikers vs FULL SENSE  Haven             1       FULL SENSE
# 2  Vision Strikers vs FULL SENSE  Haven             2  Vision Strikers
# 3  Vision Strikers vs FULL SENSE  Haven             2       FULL SENSE
# 4  Vision Strikers vs FULL SENSE  Haven             3  Vision Strikers
#
#   Loadout Value Remaining Credits              Type Outcome
# 0          3.9k              0.4k         Eco: 0-5k     Win
# 1          3.4k              0.2k         Eco: 0-5k    Loss
# ...

# %%
eco_stats = pd.read_csv("../data/vct_2021/matches/eco_stats.csv")
eco_stats.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name    Map             Team        Type  \
# 0  Vision Strikers vs FULL SENSE  Haven  Vision Strikers  Pistol Won
# 1  Vision Strikers vs FULL SENSE  Haven  Vision Strikers   Eco (won)
# 2  Vision Strikers vs FULL SENSE  Haven  Vision Strikers     $ (won)
# 3  Vision Strikers vs FULL SENSE  Haven  Vision Strikers    $$ (won)
# 4  Vision Strikers vs FULL SENSE  Haven  Vision Strikers   $$$ (won)
#
#    Initiated  Won
# 0        NaN    2
# 1        3.0    2
# 2        0.0    0
# 3        3.0    1
# 4       12.0   10

# %%
kills_stats = pd.read_csv("../data/vct_2021/matches/kills_stats.csv")
kills_stats.head()
# Out:
# /var/folders/5l/9ggb45sn6nzb744shb8z4c680000gn/T/ipykernel_16701/281047772.py:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   kills_stats = pd.read_csv("../data/vct_2021/matches/kills_stats.csv")
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name       Map             Team Player    Agent  \
# 0  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   stax   breach
# 1  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers     Rb     skye
# 2  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   k1Ng  killjoy
# 3  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   BuZz     jett
# ...

# %%
kills = pd.read_csv("../data/vct_2021/matches/kills.csv")
kills.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name       Map      Player Team Player  \
# 0  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   MaKo
# 1  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   MaKo
# 2  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   MaKo
# 3  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   MaKo
# 4  Vision Strikers vs FULL SENSE  All Maps  Vision Strikers   MaKo
#
#    Enemy Team      Enemy  Player Kills  Enemy Kills  Difference  Kill Type
# 0  FULL SENSE        PTC           3.0          7.0        -4.0  All Kills
# 1  FULL SENSE  LAMMYSNAX           5.0          1.0         4.0  All Kills
# ...

# %%
maps_played = pd.read_csv("../data/vct_2021/matches/maps_played.csv")
maps_played.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (C)
# 3  Valorant Champions 2021  Group Stage  Opening (C)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name     Map
# 0  Vision Strikers vs FULL SENSE   Haven
# 1  Vision Strikers vs FULL SENSE  Breeze
# 2  Team Vikings vs Crazy Raccoon  Icebox
# 3  Team Vikings vs Crazy Raccoon   Haven
# 4               FNATIC vs Cloud9  Icebox

# %%
maps_scores = pd.read_csv("../data/vct_2021/matches/maps_scores.csv")
maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (C)
# 3  Valorant Champions 2021  Group Stage  Opening (C)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name     Map           Team A  Team A Score  \
# 0  Vision Strikers vs FULL SENSE   Haven  Vision Strikers            13
# 1  Vision Strikers vs FULL SENSE  Breeze  Vision Strikers            13
# 2  Team Vikings vs Crazy Raccoon  Icebox     Team Vikings            13
# 3  Team Vikings vs Crazy Raccoon   Haven     Team Vikings            13
# 4               FNATIC vs Cloud9  Icebox           FNATIC            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      9                      4                    NaN
# ...

# %%
overview = pd.read_csv("../data/vct_2021/matches/overview.csv")
overview.head()
# Out:
# /var/folders/5l/9ggb45sn6nzb744shb8z4c680000gn/T/ipykernel_16701/3883227763.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   overview = pd.read_csv("../data/vct_2021/matches/overview.csv")
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name    Map Player             Team  Agents  \
# 0  Vision Strikers vs FULL SENSE  Haven   MaKo  Vision Strikers   astra
# 1  Vision Strikers vs FULL SENSE  Haven   MaKo  Vision Strikers   astra
# 2  Vision Strikers vs FULL SENSE  Haven   MaKo  Vision Strikers   astra
# 3  Vision Strikers vs FULL SENSE  Haven   stax  Vision Strikers  breach
# ...

# %%
rounds_kills = pd.read_csv("../data/vct_2021/matches/rounds_kills.csv")
rounds_kills.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name    Map Round Number  Eliminator Team  \
# 0  Vision Strikers vs FULL SENSE  Haven     Round 11  Vision Strikers
# 1  Vision Strikers vs FULL SENSE  Haven     Round 11  Vision Strikers
# 2  Vision Strikers vs FULL SENSE  Haven     Round 12  Vision Strikers
# 3  Vision Strikers vs FULL SENSE  Haven     Round 12  Vision Strikers
# 4  Vision Strikers vs FULL SENSE  Haven     Round 14  Vision Strikers
#
#   Eliminator Eliminator Agent Eliminated Team Eliminated Eliminated Agent  \
# 0       stax           breach      FULL SENSE        PTC           breach
# ...

# %%
scores = pd.read_csv("../data/vct_2021/matches/scores.csv")
scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (C)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (C)
# 4  Valorant Champions 2021  Group Stage  Opening (B)
#
#                       Match Name           Team A         Team B  \
# 0  Vision Strikers vs FULL SENSE  Vision Strikers     FULL SENSE
# 1  Team Vikings vs Crazy Raccoon     Team Vikings  Crazy Raccoon
# 2               FNATIC vs Cloud9           FNATIC         Cloud9
# 3  Gambit Esports vs Team Secret   Gambit Esports    Team Secret
# 4             Sentinels vs FURIA        Sentinels          FURIA
#
#    Team A Score  Team B Score         Match Result
# 0             2             0  Vision Strikers won
# 1             2             0     Team Vikings won
# 2             2             1           FNATIC won
# ...

# %%
team_mapping = pd.read_csv("../data/vct_2021/matches/team_mapping.csv")
team_mapping.head()
# Out:
#   Abbreviated        Full Name
# 0          VS  Vision Strikers
# 1          FS       FULL SENSE
# 2         VKS     Team Vikings
# 3          CR  Carleton Ravens
# 4         FNC           FNATIC

# %%
win_loss_methods_count = pd.read_csv("../data/vct_2021/matches/win_loss_methods_count.csv")
win_loss_methods_count.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (C)
#
#                       Match Name     Map             Team  Elimination  \
# 0  Vision Strikers vs FULL SENSE   Haven  Vision Strikers            9
# 1  Vision Strikers vs FULL SENSE   Haven       FULL SENSE            4
# 2  Vision Strikers vs FULL SENSE  Breeze  Vision Strikers            9
# 3  Vision Strikers vs FULL SENSE  Breeze       FULL SENSE            3
# 4  Team Vikings vs Crazy Raccoon  Icebox     Team Vikings            7
#
#    Detonated  Defused  Time Expiry (No Plant)  Eliminated  Defused Failed  \
# 0          2        2                       0           4               0
# ...

# %%
win_loss_methods_round_number = pd.read_csv("../data/vct_2021/matches/win_loss_methods_round_number.csv")
win_loss_methods_round_number.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2021  Group Stage  Opening (D)
# 1  Valorant Champions 2021  Group Stage  Opening (D)
# 2  Valorant Champions 2021  Group Stage  Opening (D)
# 3  Valorant Champions 2021  Group Stage  Opening (D)
# 4  Valorant Champions 2021  Group Stage  Opening (D)
#
#                       Match Name    Map  Round Number             Team  \
# 0  Vision Strikers vs FULL SENSE  Haven             1  Vision Strikers
# 1  Vision Strikers vs FULL SENSE  Haven             1       FULL SENSE
# 2  Vision Strikers vs FULL SENSE  Haven             2  Vision Strikers
# 3  Vision Strikers vs FULL SENSE  Haven             2       FULL SENSE
# 4  Vision Strikers vs FULL SENSE  Haven             3       FULL SENSE
#
#            Method Outcome
# 0     Elimination     Win
# 1      Eliminated    Loss
# 2       Detonated     Win
# 3  Failed Defused    Loss
# 4         Defused     Win

# %%
players_stats = pd.read_csv("../data/vct_2021/players_stats/players_stats.csv")
players_stats.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour North America: Last Chance Qual...  Main Event
# 1  Champions Tour North America: Last Chance Qual...  Main Event
# 2  Champions Tour North America: Last Chance Qual...  Main Event
# 3  Champions Tour North America: Last Chance Qual...  Main Event
# 4  Champions Tour North America: Last Chance Qual...  Main Event
#
#             Match Type    Player        Team  Agents  Rounds Played  Rating  \
# 0  Upper Quarterfinals      TiGG  Luminosity   astra             59    1.32
# 1  Upper Quarterfinals    aproto  Luminosity  cypher             59    1.09
# 2  Upper Quarterfinals  YaBoiDre  Luminosity    jett             59    0.84
# 3  Upper Quarterfinals    dazzLe  Luminosity    skye             59    1.04
# 4  Upper Quarterfinals     moose  Luminosity    sova             36    1.48
#
#    Average Combat Score  Kills:Deaths  ... First Deaths Per Round  Headshot %  \
# ...

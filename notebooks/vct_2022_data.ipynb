# %% [markdown]
# VALORANT Champions Tour 2022 Data from https://www.kaggle.com/datasets/ryanluong1/valorant-champion-tour-2021-2023-data
# Original data source: https://www.vlr.gg/vct-2022

# %%
import pandas as pd

# %%
agents_pick_rates = pd.read_csv("../data/vct_2022/agents/agents_pick_rates.csv")
agents_pick_rates.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour South America: Last Chance Qual...  Main Event
# 1  Champions Tour South America: Last Chance Qual...  Main Event
# 2  Champions Tour South America: Last Chance Qual...  Main Event
# 3  Champions Tour South America: Last Chance Qual...  Main Event
# 4  Champions Tour South America: Last Chance Qual...  Main Event
#
#             Match Type       Map    Agent Pick Rate
# 0  Upper Quarterfinals  All Maps  chamber       80%
# 1  Upper Quarterfinals  All Maps     fade       50%
# 2  Upper Quarterfinals  All Maps     kayo       45%
# 3  Upper Quarterfinals  All Maps     raze       45%
# 4  Upper Quarterfinals  All Maps     omen       40%

# %%
maps_stats = pd.read_csv("../data/vct_2022/agents/maps_stats.csv")
maps_stats.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour South America: Last Chance Qual...  Main Event
# 1  Champions Tour South America: Last Chance Qual...  Main Event
# 2  Champions Tour South America: Last Chance Qual...  Main Event
# 3  Champions Tour South America: Last Chance Qual...  Main Event
# 4  Champions Tour South America: Last Chance Qual...  Main Event
#
#             Match Type       Map  Total Maps Played  \
# 0  Upper Quarterfinals  All Maps                 10
# 1  Upper Quarterfinals    Ascent                  3
# 2  Upper Quarterfinals  Fracture                  3
# 3  Upper Quarterfinals     Haven                  2
# 4  Upper Quarterfinals      Bind                  1
#
#   Attacker Side Win Percentage Defender Side Win Percentage
# 0                          52%                          48%
# 1                          48%                          52%
# 2                          54%                          46%
# ...

# %%
teams_picked_agents = pd.read_csv("../data/vct_2022/agents/teams_picked_agents.csv")
teams_picked_agents.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour South America: Last Chance Qual...  Main Event
# 1  Champions Tour South America: Last Chance Qual...  Main Event
# 2  Champions Tour South America: Last Chance Qual...  Main Event
# 3  Champions Tour South America: Last Chance Qual...  Main Event
# 4  Champions Tour South America: Last Chance Qual...  Main Event
#
#             Match Type    Map               Team Agent Picked  \
# 0  Upper Quarterfinals  Haven  Ninjas In Pyjamas      chamber
# 1  Upper Quarterfinals  Haven  Ninjas In Pyjamas         kayo
# 2  Upper Quarterfinals  Haven  Ninjas In Pyjamas         omen
# 3  Upper Quarterfinals  Haven  Ninjas In Pyjamas         neon
# 4  Upper Quarterfinals  Haven  Ninjas In Pyjamas         skye
#
#    Total Wins By Map  Total Loss By Map  Total Maps Played
# 0                  0                  1                  1
# 1                  0                  1                  1
# ...

# %%
players_ids = pd.read_csv("../data/vct_2022/ids/players_ids.csv")
players_ids.head()
# Out:
#       Player  Player ID
# 0     Benkai       9802
# 1      d4v41       9803
# 2  mindfreak       9800
# 3   f0rsakeN       9801
# 4     Jinggg       7378

# %%
teams_ids = pd.read_csv("../data/vct_2022/ids/teams_ids.csv")
teams_ids.head()
# Out:
#             Team  Team ID
# 0      Paper Rex      624
# 1  EDward Gaming     1120
# 2       Leviatán     2359
# 3    Team Liquid      474
# 4  ZETA DIVISION     5448

# %%
tournaments_stages_match_types_ids = pd.read_csv("../data/vct_2022/ids/tournaments_stages_match_types_ids.csv")
tournaments_stages_match_types_ids.head()
# Out:
#                                    Tournament  Tournament ID       Stage  \
# 0  Champions Tour EMEA: Last Chance Qualifier           1117  Main Event
# 1  Champions Tour EMEA: Last Chance Qualifier           1117  Main Event
# 2  Champions Tour EMEA: Last Chance Qualifier           1117  Main Event
# 3  Champions Tour EMEA: Last Chance Qualifier           1117  Main Event
# 4  Champions Tour EMEA: Last Chance Qualifier           1117  Main Event
#
#    Stage ID           Match Type  Match Type ID
# 0    2163.0  Upper Quarterfinals        12604.0
# 1    2163.0     Upper Semifinals        12605.0
# 2    2163.0          Upper Final        12606.0
# 3    2163.0          Grand Final        12607.0
# 4    2163.0        Lower Round 1        12608.0

# %%
tournaments_stages_matches_games_ids = pd.read_csv("../data/vct_2022/ids/tournaments_stages_matches_games_ids.csv")
tournaments_stages_matches_games_ids.head()
# Out:
#                 Tournament  Tournament ID        Stage  Stage ID   Match Type  \
# 0  Valorant Champions 2022           1015  Group Stage      2183  Opening (A)
# 1  Valorant Champions 2022           1015  Group Stage      2183  Opening (A)
# 2  Valorant Champions 2022           1015  Group Stage      2183  Opening (A)
# 3  Valorant Champions 2022           1015  Group Stage      2183  Opening (A)
# 4  Valorant Champions 2022           1015  Group Stage      2183  Opening (A)
#
#                    Match Name  Match ID     Map  Game ID
# 0  Paper Rex vs EDward Gaming    130617   Pearl    95029
# 1  Paper Rex vs EDward Gaming    130617  Icebox    95030
# 2  Paper Rex vs EDward Gaming    130617   Haven    95031
# 3     Leviatán vs Team Liquid    130618   Haven    95032
# 4     Leviatán vs Team Liquid    130618  Ascent    95033

# %%
draft_phase = pd.read_csv("../data/vct_2022/matches/draft_phase.csv")
draft_phase.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name           Team Action       Map
# 0  Paper Rex vs EDward Gaming  EDward Gaming    ban      Bind
# 1  Paper Rex vs EDward Gaming      Paper Rex    ban  Fracture
# 2  Paper Rex vs EDward Gaming  EDward Gaming   pick     Pearl
# 3  Paper Rex vs EDward Gaming      Paper Rex   pick    Icebox
# 4  Paper Rex vs EDward Gaming  EDward Gaming    ban    Ascent

# %%
eco_rounds = pd.read_csv("../data/vct_2022/matches/eco_rounds.csv")
eco_rounds.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name    Map  Round Number           Team  \
# 0  Paper Rex vs EDward Gaming  Pearl             1      Paper Rex
# 1  Paper Rex vs EDward Gaming  Pearl             1  EDward Gaming
# 2  Paper Rex vs EDward Gaming  Pearl             2      Paper Rex
# 3  Paper Rex vs EDward Gaming  Pearl             2  EDward Gaming
# 4  Paper Rex vs EDward Gaming  Pearl             3      Paper Rex
#
#   Loadout Value Remaining Credits              Type Outcome
# 0          3.7k              0.1k         Eco: 0-5k    Loss
# 1          4.0k              0.2k         Eco: 0-5k     Win
# 2          1.2k              9.6k         Eco: 0-5k    Loss
# ...

# %%
eco_stats = pd.read_csv("../data/vct_2022/matches/eco_stats.csv")
eco_stats.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name    Map       Team        Type  Initiated  Won
# 0  Paper Rex vs EDward Gaming  Pearl  Paper Rex  Pistol Won        NaN    1
# 1  Paper Rex vs EDward Gaming  Pearl  Paper Rex   Eco (won)        3.0    1
# 2  Paper Rex vs EDward Gaming  Pearl  Paper Rex     $ (won)        2.0    1
# 3  Paper Rex vs EDward Gaming  Pearl  Paper Rex    $$ (won)        8.0    5
# 4  Paper Rex vs EDward Gaming  Pearl  Paper Rex   $$$ (won)       11.0    6

# %%
kills_stats = pd.read_csv("../data/vct_2022/matches/kills_stats.csv")
kills_stats.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name       Map       Team     Player    Agent    2k  \
# 0  Paper Rex vs EDward Gaming  All Maps  Paper Rex     Jinggg     raze  13.0
# 1  Paper Rex vs EDward Gaming  All Maps  Paper Rex  mindfreak    astra   4.0
# 2  Paper Rex vs EDward Gaming  All Maps  Paper Rex   f0rsakeN  chamber   9.0
# 3  Paper Rex vs EDward Gaming  All Maps  Paper Rex     Benkai     fade   4.0
# 4  Paper Rex vs EDward Gaming  All Maps  Paper Rex      d4v41     sage   5.0
#
#     3k   4k  5k  1v1  1v2  1v3  1v4  1v5  Econ  Spike Plants  Spike Defuse
# 0  3.0  1.0 NaN  NaN  NaN  NaN  NaN  NaN  59.0           1.0           0.0
# ...

# %%
kills = pd.read_csv("../data/vct_2022/matches/kills.csv")
kills.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name       Map Player Team Player     Enemy Team  \
# 0  Paper Rex vs EDward Gaming  All Maps   Paper Rex  d4v41  EDward Gaming
# 1  Paper Rex vs EDward Gaming  All Maps   Paper Rex  d4v41  EDward Gaming
# 2  Paper Rex vs EDward Gaming  All Maps   Paper Rex  d4v41  EDward Gaming
# 3  Paper Rex vs EDward Gaming  All Maps   Paper Rex  d4v41  EDward Gaming
# 4  Paper Rex vs EDward Gaming  All Maps   Paper Rex  d4v41  EDward Gaming
#
#      Enemy  Player Kills  Enemy Kills  Difference  Kill Type
# 0  Haodong           8.0          8.0         0.0  All Kills
# 1   nobody          12.0          9.0         3.0  All Kills
# ...

# %%
maps_played = pd.read_csv("../data/vct_2022/matches/maps_played.csv")
maps_played.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map
# 0  Paper Rex vs EDward Gaming   Pearl
# 1  Paper Rex vs EDward Gaming  Icebox
# 2  Paper Rex vs EDward Gaming   Haven
# 3     Leviatán vs Team Liquid   Haven
# 4     Leviatán vs Team Liquid  Ascent

# %%
maps_scores = pd.read_csv("../data/vct_2022/matches/maps_scores.csv")
maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map     Team A  Team A Score  \
# 0  Paper Rex vs EDward Gaming   Pearl  Paper Rex            13
# 1  Paper Rex vs EDward Gaming  Icebox  Paper Rex             5
# 2  Paper Rex vs EDward Gaming   Haven  Paper Rex            13
# 3     Leviatán vs Team Liquid   Haven   Leviatán            13
# 4     Leviatán vs Team Liquid  Ascent   Leviatán            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      7                    NaN
# 1                      2                      3                    NaN
# ...

# %%
overview = pd.read_csv("../data/vct_2022/matches/overview.csv")
overview.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name    Map  Player       Team Agents  Rating  \
# 0  Paper Rex vs EDward Gaming  Pearl  Benkai  Paper Rex   fade    1.31
# 1  Paper Rex vs EDward Gaming  Pearl  Benkai  Paper Rex   fade    1.18
# 2  Paper Rex vs EDward Gaming  Pearl  Benkai  Paper Rex   fade    1.45
# 3  Paper Rex vs EDward Gaming  Pearl   d4v41  Paper Rex   sage    1.15
# 4  Paper Rex vs EDward Gaming  Pearl   d4v41  Paper Rex   sage    1.04
#
#    Average Combat Score  ...  Deaths  Assists  Kills - Deaths (KD)  \
# 0                 242.0  ...    16.0     13.0                  6.0
# 1                 243.0  ...     9.0      5.0                  2.0
# ...

# %%
rounds_kills = pd.read_csv("../data/vct_2022/matches/rounds_kills.csv")
rounds_kills.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name    Map Round Number Eliminator Team Eliminator  \
# 0  Paper Rex vs EDward Gaming  Pearl      Round 2       Paper Rex     Jinggg
# 1  Paper Rex vs EDward Gaming  Pearl      Round 2       Paper Rex     Jinggg
# 2  Paper Rex vs EDward Gaming  Pearl     Round 11       Paper Rex     Jinggg
# 3  Paper Rex vs EDward Gaming  Pearl     Round 11       Paper Rex     Jinggg
# 4  Paper Rex vs EDward Gaming  Pearl     Round 14       Paper Rex     Jinggg
#
#   Eliminator Agent Eliminated Team Eliminated Eliminated Agent Kill Type
# 0             raze   EDward Gaming     Smoggy             kayo        2k
# ...

# %%
scores = pd.read_csv("../data/vct_2022/matches/scores.csv")
scores.head()
# Out:
#                 Tournament        Stage    Match Type  \
# 0  Valorant Champions 2022  Group Stage   Opening (A)
# 1  Valorant Champions 2022  Group Stage   Opening (A)
# 2  Valorant Champions 2022  Group Stage   Opening (B)
# 3  Valorant Champions 2022  Group Stage   Opening (B)
# 4  Valorant Champions 2022  Group Stage  Winner's (A)
#
#                      Match Name         Team A         Team B  Team A Score  \
# 0    Paper Rex vs EDward Gaming      Paper Rex  EDward Gaming             2
# 1       Leviatán vs Team Liquid       Leviatán    Team Liquid             2
# 2         ZETA DIVISION vs LOUD  ZETA DIVISION           LOUD             0
# 3  OpTic Gaming vs BOOM Esports   OpTic Gaming   BOOM Esports             2
# 4         Paper Rex vs Leviatán      Paper Rex       Leviatán             0
#
#    Team B Score      Match Result
# 0             1     Paper Rex won
# 1             0      Leviatán won
# 2             2          LOUD won
# 3             1  OpTic Gaming won
# ...

# %%
team_mapping = pd.read_csv("../data/vct_2022/matches/team_mapping.csv")
team_mapping.head()
# Out:
#   Abbreviated      Full Name
# 0         PRX      Paper Rex
# 1         EDG  EDward Gaming
# 2         LEV       Leviatán
# 3          TL    Team Liquid
# 4        ZETA  ZETA DIVISION

# %%
win_loss_methods_count = pd.read_csv("../data/vct_2022/matches/win_loss_methods_count.csv")
win_loss_methods_count.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name     Map           Team  Elimination  Detonated  \
# 0  Paper Rex vs EDward Gaming   Pearl      Paper Rex           11          0
# 1  Paper Rex vs EDward Gaming   Pearl  EDward Gaming            7          1
# 2  Paper Rex vs EDward Gaming  Icebox      Paper Rex            5          0
# 3  Paper Rex vs EDward Gaming  Icebox  EDward Gaming           11          2
# 4  Paper Rex vs EDward Gaming   Haven      Paper Rex            9          1
#
#    Defused  Time Expiry (No Plant)  Eliminated  Defused Failed  \
# 0        1                       1           7               1
# ...

# %%
win_loss_methods_round_number = pd.read_csv("../data/vct_2022/matches/win_loss_methods_round_number.csv")
win_loss_methods_round_number.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2022  Group Stage  Opening (A)
# 1  Valorant Champions 2022  Group Stage  Opening (A)
# 2  Valorant Champions 2022  Group Stage  Opening (A)
# 3  Valorant Champions 2022  Group Stage  Opening (A)
# 4  Valorant Champions 2022  Group Stage  Opening (A)
#
#                    Match Name    Map  Round Number           Team  \
# 0  Paper Rex vs EDward Gaming  Pearl             1  EDward Gaming
# 1  Paper Rex vs EDward Gaming  Pearl             1      Paper Rex
# 2  Paper Rex vs EDward Gaming  Pearl             2  EDward Gaming
# 3  Paper Rex vs EDward Gaming  Pearl             2      Paper Rex
# 4  Paper Rex vs EDward Gaming  Pearl             3  EDward Gaming
#
#         Method Outcome
# 0  Elimination     Win
# 1   Eliminated    Loss
# 2  Elimination     Win
# 3   Eliminated    Loss
# 4      Defused     Win

# %%
players_stats = pd.read_csv("../data/vct_2022/players_stats/players_stats.csv")
players_stats.head()
# Out:
#                                    Tournament       Stage  \
# 0  Champions Tour EMEA: Last Chance Qualifier  Main Event
# 1  Champions Tour EMEA: Last Chance Qualifier  Main Event
# 2  Champions Tour EMEA: Last Chance Qualifier  Main Event
# 3  Champions Tour EMEA: Last Chance Qualifier  Main Event
# 4  Champions Tour EMEA: Last Chance Qualifier  Main Event
#
#             Match Type  Player          Team             Agents  \
# 0  Upper Quarterfinals  Redgar  M3 Champions              astra
# 1  Upper Quarterfinals  Redgar  M3 Champions               omen
# 2  Upper Quarterfinals  Redgar  M3 Champions               sova
# 3  Upper Quarterfinals  Redgar  M3 Champions  omen, astra, sova
# 4  Upper Quarterfinals    nAts  M3 Champions            chamber
#
#    Rounds Played  Rating  Average Combat Score  Kills:Deaths  ...  \
# 0             19    1.18                 198.0          1.30  ...
# 1             22    0.82                 159.0          0.71  ...
# ...

# %% [markdown]
# VALORANT Champions Tour 2023 Data from https://www.kaggle.com/datasets/ryanluong1/valorant-champion-tour-2021-2023-data
# Original data source: https://www.vlr.gg/vct-2023

# %%
import pandas as pd

# %%
agents_pick_rates = pd.read_csv("../data/vct_2023/agents/agents_pick_rates.csv")
agents_pick_rates.head()
# Out:
#                                         Tournament     Stage      Match Type  \
# 0  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 1  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 2  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 3  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 4  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
#
#         Map    Agent Pick Rate
# 0  All Maps     omen       67%
# 1  All Maps     skye       58%
# 2  All Maps     raze       58%
# 3  All Maps   breach       58%
# 4  All Maps  killjoy       58%

# %%
maps_stats = pd.read_csv("../data/vct_2023/agents/maps_stats.csv")
maps_stats.head()
# Out:
#                                         Tournament     Stage      Match Type  \
# 0  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 1  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 2  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 3  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 4  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
#
#         Map  Total Maps Played Attacker Side Win Percentage  \
# 0  All Maps                  6                          47%
# 1     Haven                  2                          40%
# 2      Bind                  1                          58%
# 3  Fracture                  1                          71%
# 4     Lotus                  1                          50%
#
#   Defender Side Win Percentage
# 0                          53%
# 1                          60%
# 2                          42%
# ...

# %%
teams_picked_agents = pd.read_csv("../data/vct_2023/agents/teams_picked_agents.csv")
teams_picked_agents.head()
# Out:
#                                         Tournament     Stage      Match Type  \
# 0  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 1  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 2  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 3  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
# 4  Champions Tour 2023: EMEA Last Chance Qualifier  Playoffs  Knockout Round
#
#         Map           Team Agent Picked  Total Wins By Map  Total Loss By Map  \
# 0  Fracture  Team Heretics         omen                  0                  1
# 1  Fracture  Team Heretics         skye                  0                  1
# 2  Fracture  Team Heretics         raze                  0                  1
# 3  Fracture  Team Heretics        viper                  0                  1
# 4  Fracture  Team Heretics       cypher                  0                  1
#
#    Total Maps Played
# ...

# %%
players_ids = pd.read_csv("../data/vct_2023/ids/players_ids.csv")
players_ids.head()
# Out:
#     Player  Player ID
# 0     nAts        457
# 1     Sayf        312
# 2  soulcas        101
# 3   Jamppi       9780
# 4   Redgar       1427

# %%
teams_ids = pd.read_csv("../data/vct_2023/ids/teams_ids.csv")
teams_ids.head()
# Out:
#             Team  Team ID
# 0    Team Liquid      474
# 1  Natus Vincere     4915
# 2            DRX     8185
# 3           LOUD     6961
# 4    FUT Esports     1184

# %%
tournaments_stages_match_types_ids = pd.read_csv("../data/vct_2023/ids/tournaments_stages_match_types_ids.csv")
tournaments_stages_match_types_ids.head()
# Out:
#                                         Tournament  Tournament ID     Stage  \
# 0  Champions Tour 2023: EMEA Last Chance Qualifier           1659  Playoffs
# 1  Champions Tour 2023: EMEA Last Chance Qualifier           1659  Playoffs
# 2  Champions Tour 2023: EMEA Last Chance Qualifier           1659  Playoffs
# 3  Champions Tour 2023: EMEA Last Chance Qualifier           1659  Playoffs
# 4  Champions Tour 2023: EMEA Last Chance Qualifier           1659  Playoffs
#
#    Stage ID        Match Type  Match Type ID
# 0    3147.0    Knockout Round        19811.0
# 1    3147.0  Upper Semifinals        19812.0
# 2    3147.0       Upper Final        19813.0
# 3    3147.0       Grand Final        19814.0
# 4    3147.0     Lower Round 1        19816.0

# %%
tournaments_stages_matches_games_ids = pd.read_csv("../data/vct_2023/ids/tournaments_stages_matches_games_ids.csv")
tournaments_stages_matches_games_ids.head()
# Out:
#                 Tournament  Tournament ID        Stage  Stage ID   Match Type  \
# 0  Valorant Champions 2023           1657  Group Stage      3145  Opening (D)
# 1  Valorant Champions 2023           1657  Group Stage      3145  Opening (D)
# 2  Valorant Champions 2023           1657  Group Stage      3145  Opening (D)
# 3  Valorant Champions 2023           1657  Group Stage      3145  Opening (D)
# 4  Valorant Champions 2023           1657  Group Stage      3145  Opening (D)
#
#                      Match Name  Match ID       Map  Game ID
# 0  Team Liquid vs Natus Vincere    247100  Fracture   137395
# 1  Team Liquid vs Natus Vincere    247100      Bind   137396
# 2                   DRX vs LOUD    247101     Lotus   137398
# 3                   DRX vs LOUD    247101     Split   137399
# 4                   DRX vs LOUD    247101    Ascent   137400

# %%
draft_phase = pd.read_csv("../data/vct_2023/matches/draft_phase.csv")
draft_phase.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name           Team Action       Map
# 0  Team Liquid vs Natus Vincere  Natus Vincere    ban     Haven
# 1  Team Liquid vs Natus Vincere    Team Liquid    ban     Pearl
# 2  Team Liquid vs Natus Vincere  Natus Vincere   pick  Fracture
# 3  Team Liquid vs Natus Vincere    Team Liquid   pick      Bind
# 4  Team Liquid vs Natus Vincere  Natus Vincere    ban     Lotus

# %%
eco_rounds = pd.read_csv("../data/vct_2023/matches/eco_rounds.csv")
eco_rounds.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map  Round Number           Team  \
# 0  Team Liquid vs Natus Vincere  Fracture             1    Team Liquid
# 1  Team Liquid vs Natus Vincere  Fracture             1  Natus Vincere
# 2  Team Liquid vs Natus Vincere  Fracture             2    Team Liquid
# 3  Team Liquid vs Natus Vincere  Fracture             2  Natus Vincere
# 4  Team Liquid vs Natus Vincere  Fracture             3    Team Liquid
#
#   Loadout Value Remaining Credits              Type Outcome
# 0          3.6k              0.4k         Eco: 0-5k     Win
# 1          3.5k              0.3k         Eco: 0-5k    Loss
# ...

# %%
eco_stats = pd.read_csv("../data/vct_2023/matches/eco_stats.csv")
eco_stats.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map         Team        Type  Initiated  \
# 0  Team Liquid vs Natus Vincere  Fracture  Team Liquid  Pistol Won        NaN
# 1  Team Liquid vs Natus Vincere  Fracture  Team Liquid   Eco (won)        2.0
# 2  Team Liquid vs Natus Vincere  Fracture  Team Liquid     $ (won)        2.0
# 3  Team Liquid vs Natus Vincere  Fracture  Team Liquid    $$ (won)        8.0
# 4  Team Liquid vs Natus Vincere  Fracture  Team Liquid   $$$ (won)       12.0
#
#    Won
# 0    2
# 1    2
# 2    0
# 3    4
# 4    5

# %%
kills_stats = pd.read_csv("../data/vct_2023/matches/kills_stats.csv")
kills_stats.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map         Team   Player   Agent    2k  \
# 0  Team Liquid vs Natus Vincere  All Maps  Team Liquid  soulcas   astra   4.0
# 1  Team Liquid vs Natus Vincere  All Maps  Team Liquid     Sayf  breach   8.0
# 2  Team Liquid vs Natus Vincere  All Maps  Team Liquid     nAts   viper  13.0
# 3  Team Liquid vs Natus Vincere  All Maps  Team Liquid   Redgar    sova   8.0
# 4  Team Liquid vs Natus Vincere  All Maps  Team Liquid   Jamppi    neon   9.0
#
#     3k   4k   5k  1v1  1v2  1v3  1v4  1v5  Econ  Spike Plants  Spike Defuse
# 0  1.0  NaN  NaN  1.0  NaN  NaN  NaN  NaN    30             2             0
# ...

# %%
kills = pd.read_csv("../data/vct_2023/matches/kills.csv")
kills.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map  Player Team  Player     Enemy Team  \
# 0  Team Liquid vs Natus Vincere  All Maps  Team Liquid  Jamppi  Natus Vincere
# 1  Team Liquid vs Natus Vincere  All Maps  Team Liquid  Jamppi  Natus Vincere
# 2  Team Liquid vs Natus Vincere  All Maps  Team Liquid  Jamppi  Natus Vincere
# 3  Team Liquid vs Natus Vincere  All Maps  Team Liquid  Jamppi  Natus Vincere
# 4  Team Liquid vs Natus Vincere  All Maps  Team Liquid  Jamppi  Natus Vincere
#
#       Enemy  Player Kills  Enemy Kills  Difference  Kill Type
# 0     ANGE1           9.0         12.0        -3.0  All Kills
# ...

# %%
maps_played = pd.read_csv("../data/vct_2023/matches/maps_played.csv")
maps_played.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map
# 0  Team Liquid vs Natus Vincere  Fracture
# 1  Team Liquid vs Natus Vincere      Bind
# 2                   DRX vs LOUD     Lotus
# 3                   DRX vs LOUD     Split
# 4                   DRX vs LOUD    Ascent

# %%
maps_scores = pd.read_csv("../data/vct_2023/matches/maps_scores.csv")
maps_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map       Team A  Team A Score  \
# 0  Team Liquid vs Natus Vincere  Fracture  Team Liquid            11
# 1  Team Liquid vs Natus Vincere      Bind  Team Liquid            15
# 2                   DRX vs LOUD     Lotus          DRX            13
# 3                   DRX vs LOUD     Split          DRX            13
# 4                   DRX vs LOUD    Ascent          DRX            13
#
#    Team A Attacker Score  Team A Defender Score  Team A Overtime Score  \
# 0                      6                      5                    NaN
# 1                      7                      5                    3.0
# ...

# %%
overview = pd.read_csv("../data/vct_2023/matches/overview.csv")
overview.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map Player         Team  Agents  Rating  \
# 0  Team Liquid vs Natus Vincere  Fracture   nAts  Team Liquid   viper    1.20
# 1  Team Liquid vs Natus Vincere  Fracture   nAts  Team Liquid   viper    1.40
# 2  Team Liquid vs Natus Vincere  Fracture   nAts  Team Liquid   viper    1.00
# 3  Team Liquid vs Natus Vincere  Fracture   Sayf  Team Liquid  breach    0.96
# 4  Team Liquid vs Natus Vincere  Fracture   Sayf  Team Liquid  breach    0.46
#
#    Average Combat Score  ...  Deaths  Assists  Kills - Deaths (KD)  \
# 0                 242.0  ...    15.0      3.0                  5.0
# ...

# %%
rounds_kills = pd.read_csv("../data/vct_2023/matches/rounds_kills.csv")
rounds_kills.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map Round Number Eliminator Team  \
# 0  Team Liquid vs Natus Vincere  Fracture      Round 1     Team Liquid
# 1  Team Liquid vs Natus Vincere  Fracture      Round 1     Team Liquid
# 2  Team Liquid vs Natus Vincere  Fracture     Round 17     Team Liquid
# 3  Team Liquid vs Natus Vincere  Fracture     Round 17     Team Liquid
# 4  Team Liquid vs Natus Vincere  Fracture     Round 17     Team Liquid
#
#   Eliminator Eliminator Agent Eliminated Team Eliminated Eliminated Agent  \
# 0    soulcas            astra   Natus Vincere       cNed          killjoy
# ...

# %%
scores = pd.read_csv("../data/vct_2023/matches/scores.csv")
scores.head()
# Out:
#                 Tournament        Stage    Match Type  \
# 0  Valorant Champions 2023  Group Stage   Opening (D)
# 1  Valorant Champions 2023  Group Stage   Opening (D)
# 2  Valorant Champions 2023  Group Stage   Opening (B)
# 3  Valorant Champions 2023  Group Stage   Opening (B)
# 4  Valorant Champions 2023  Group Stage  Winner's (D)
#
#                          Match Name         Team A           Team B  \
# 0      Team Liquid vs Natus Vincere    Team Liquid    Natus Vincere
# 1                       DRX vs LOUD            DRX             LOUD
# 2                 FUT Esports vs T1    FUT Esports               T1
# 3  Evil Geniuses vs FunPlus Phoenix  Evil Geniuses  FunPlus Phoenix
# 4              Natus Vincere vs DRX  Natus Vincere              DRX
#
#    Team A Score  Team B Score       Match Result
# 0             0             2  Natus Vincere won
# 1             2             1            DRX won
# 2             2             0    FUT Esports won
# ...

# %%
team_mapping = pd.read_csv("../data/vct_2023/matches/team_mapping.csv")
team_mapping.head()
# Out:
#   Abbreviated      Full Name
# 0          TL    Team Liquid
# 1        NAVI  Natus Vincere
# 2         DRX            DRX
# 3        LOUD           LOUD
# 4         FUT    FUT Esports

# %%
win_loss_methods_count = pd.read_csv("../data/vct_2023/matches/win_loss_methods_count.csv")
win_loss_methods_count.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map           Team  Elimination  \
# 0  Team Liquid vs Natus Vincere  Fracture    Team Liquid            8
# 1  Team Liquid vs Natus Vincere  Fracture  Natus Vincere            6
# 2  Team Liquid vs Natus Vincere      Bind    Team Liquid           11
# 3  Team Liquid vs Natus Vincere      Bind  Natus Vincere           11
# 4                   DRX vs LOUD     Lotus            DRX            5
#
#    Detonated  Defused  Time Expiry (No Plant)  Eliminated  Defused Failed  \
# 0          2        1                       0           6               5
# ...

# %%
win_loss_methods_round_number = pd.read_csv("../data/vct_2023/matches/win_loss_methods_round_number.csv")
win_loss_methods_round_number.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2023  Group Stage  Opening (D)
# 1  Valorant Champions 2023  Group Stage  Opening (D)
# 2  Valorant Champions 2023  Group Stage  Opening (D)
# 3  Valorant Champions 2023  Group Stage  Opening (D)
# 4  Valorant Champions 2023  Group Stage  Opening (D)
#
#                      Match Name       Map  Round Number           Team  \
# 0  Team Liquid vs Natus Vincere  Fracture             1    Team Liquid
# 1  Team Liquid vs Natus Vincere  Fracture             1  Natus Vincere
# 2  Team Liquid vs Natus Vincere  Fracture             2    Team Liquid
# 3  Team Liquid vs Natus Vincere  Fracture             2  Natus Vincere
# 4  Team Liquid vs Natus Vincere  Fracture             3    Team Liquid
#
#         Method Outcome
# 0  Elimination     Win
# 1   Eliminated    Loss
# 2  Elimination     Win
# 3   Eliminated    Loss
# 4  Elimination     Win

# %%
players_stats = pd.read_csv("../data/vct_2023/players_stats/players_stats.csv")
players_stats.head()
# Out:
#                                           Tournament       Stage  \
# 0  Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 1  Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 2  Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 3  Champions Tour 2023: Americas Last Chance Qual...  Main Event
# 4  Champions Tour 2023: Americas Last Chance Qual...  Main Event
#
#       Match Type   Player         Team           Agents  Rounds Played  \
# 0  Upper Round 1   Melser  KRÜ Esports        brimstone             20
# 1  Upper Round 1   Melser  KRÜ Esports             omen             21
# 2  Upper Round 1   Melser  KRÜ Esports  brimstone, omen             41
# 3  Upper Round 1  DaveeyS  KRÜ Esports          killjoy             21
# 4  Upper Round 1   keznit  KRÜ Esports             raze             41
#
#    Rating  Average Combat Score  Kills:Deaths  ... First Deaths Per Round  \
# ...
